# %%
# Import

import numpy as np
from wrappers.mathlib import MathLib

mathlib = MathLib()

# %%
# --- tests ---
try:
    print(f"10 + 5 = {mathlib.addition(10, 5)}") # 15.0
    print(f"10 / 2 = {mathlib.division(10, 2)}") # 5.0
    print(f"10 / 0 = {mathlib.division(10, 0)}") # Devrait lever une exception
except RuntimeError as e:
    print(f"Erreur : {e}")
# Out:
# 10 + 5 = 15.0
# 10 / 2 = 5.0
# Erreur : Division by Zero

# %%
# Import

import numpy as np
from api.wrappers.mathlib import MathLib

mathlib = MathLib(dll_folder="libc", dll_basename="mathlib")
# Out:
# Chargement de la bibliothèque : libc\dll\mathlib.dll

# %%
# Tests

try:
    print(f"10 + 5 = {mathlib.addition(10, 5)}") # 15.0
    print(f"10 / 2 = {mathlib.division(10, 2)}") # 5.0
    print(f"10 / 0 = {mathlib.division(10, 0)}") # raise error
except RuntimeError as e:
    print(f"Error: {e}")
# Out:
# 10 + 5 = 15.0
# 10 / 2 = 5.0
# Error: mathlib: Division by Zero

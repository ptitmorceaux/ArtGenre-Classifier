# %% [markdown]
# ### Import Basic

# %%
import sys
import os
import numpy as np

sys.path.append(os.path.abspath(os.path.join('..')))

# %% [markdown]
# ### Compile `libc`

# %%
try:
    os.system("make -C .. clean && make -C .. all")
except Exception as e:
    print(f"Build failed: {e}")
    sys.exit(1)

# %% [markdown]
# ### Import Program

# %%
# from engine.core.processing import DataProcessor

# data_processor = DataProcessor()

# %%
from engine.bindings.mathlib import MathLib
from engine.bindings.model import ModelLib

try:
    mathlib = MathLib(lib_folder="../libc")
    modellib = ModelLib(lib_folder="../libc")

except Exception as e:
    print(f"Error: {e}")
    raise SystemExit(1)

# %% [markdown]
# ### Load Dataset

# %%
try:
    mathlib.division(10, 0)
    assert False
except RuntimeError as e:
    if str(e) != "mathlib._get_error(): Division by Zero":
        print(f"Error: {e}")

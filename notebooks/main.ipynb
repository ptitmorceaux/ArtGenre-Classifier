# %% [markdown]
# ### Import

# %%
import sys
import os
import numpy as np

# %%
sys.path.append(os.path.abspath(os.path.join('..')))
from bindings.mathlib import MathLib
from bindings.predict import PredictLib

# %%
try:
    mathlib = MathLib(lib_folder="../libc")
    predictlib = PredictLib(lib_folder="../libc")

except Exception as e:
    print(f"Error: {e}")
    raise SystemExit(1)

# %% [markdown]
# ### Tests

# %%
try:
    assert mathlib.addition(10, 5) == 15.0
    assert mathlib.subtraction(10, 5) == 5.0
    assert mathlib.multiplication(10, 5) == 50.0
    assert mathlib.division(10, 2) == 5.0
    assert mathlib.power(2, 3) == 8.0
except RuntimeError as e:
    print(f"Error: {e}")

# %%
try:
    mathlib.division(10, 0)
    assert False
except RuntimeError as e:
    if str(e) != "mathlib._get_error(): Division by Zero":
        print(f"Error: {e}")

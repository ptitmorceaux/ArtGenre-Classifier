# %% [markdown]
# ### Restart Kernel

# %%
from IPython.display import display, Javascript
display(Javascript("Jupyter.notebook.kernel.restart()"))

# %% [markdown]
# ### Import Prerequis

# %%
import sys
import os
import subprocess

sys.path.append(os.path.abspath(os.path.join('..')))

# %% [markdown]
# ### Functions

# %%
def run_cmd(cmd: str):
    try:
        result = subprocess.run(
            cmd,
            shell=True,
            capture_output=True,
            text=True
        )
        print(result.stdout)

        if result.stderr:
            print(result.stderr)
        
        if result.returncode != 0:
            print(f"Failure with exit code {result.returncode}")
            sys.exit(1)

    except Exception as e:
        print(f"Failure: {e}")
        sys.exit(1)

# %% [markdown]
# ### Tests

# %%
print("Pylint Ruff check and fix:")
run_cmd("ruff check ../ --fix")
# Out:
# Pylint Ruff check and fix:
# All checks passed!

# %%
print("Running pytest:")
run_cmd("pytest ../")
# Out:
# Running pytest:
# ============================= test session starts =============================
# platform win32 -- Python 3.14.3, pytest-9.0.2, pluggy-1.6.0
# rootdir: c:\Users\milha\Documents\ESGI\3ESGI CL A ALT RO\PA\ArtGenre-Classifier
#
# Compilation of libc...
# OK: Compilation succeeded.
# collected 50 items
#
# ..\pytest\interop\test_001_math.py ..........                            [ 20%]
# ..\pytest\interop\test_002_array.py .........................            [ 70%]
# ..\pytest\interop\test_003_random.py ...............                     [100%]
#
# ============================= 50 passed in 1.61s ==============================
